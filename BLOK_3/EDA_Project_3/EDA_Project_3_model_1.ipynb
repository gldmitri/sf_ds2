# %%
import pandas as pd
import numpy as np

# %%
h1 = pd.read_csv('C:\\Users\\Glavatskih-DE\\Downloads\\PY_kurs\\CSV\\hotels.csv')
h1.head(3)
# Out:
#                                        hotel_address  \
# 0  Stratton Street Mayfair Westminster Borough Lo...
# 1  130 134 Southampton Row Camden London WC1B 5AF...
# 2   151 bis Rue de Rennes 6th arr 75006 Paris France
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           581   2/19/2016            8.4
# 1                           299   1/12/2017            8.3
# 2                            32  10/18/2016            8.9
#
#                           hotel_name reviewer_nationality  \
# 0                 The May Fair Hotel      United Kingdom
# 1    Mercure London Bloomsbury Hotel      United Kingdom
# 2  Legend Saint Germain by Elegancia               China
#
#        negative_review  review_total_negative_word_counts  \
# 0             Leaving                                   3
# 1       poor breakfast                                  3
# 2   No kettle in room                                   6
#
#    total_number_of_reviews      positive_review  \
# 0                     1994   Staff were amazing
# 1                     1361             location
# 2                      406          No Positive
#
#    review_total_positive_word_counts  \
# 0                                  4
# 1                                  2
# 2                                  0
#
#    total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 0                                           7            10.0
# 1                                          14             6.3
# 2                                          14             7.5
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Studio Suite ...           531 day
# 1  [' Business trip ', ' Couple ', ' Standard Dou...           203 day
# 2  [' Leisure trip ', ' Solo traveler ', ' Modern...           289 day
#
#          lat       lng
# 0  51.507894 -0.143671
# 1  51.521009 -0.123097
# 2  48.845377  2.325643

# %%
h1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               386803 non-null  object
#  1   additional_number_of_scoring                386803 non-null  int64
#  2   review_date                                 386803 non-null  object
#  3   average_score                               386803 non-null  float64
#  4   hotel_name                                  386803 non-null  object
#  5   reviewer_nationality                        386803 non-null  object
#  6   negative_review                             386803 non-null  object
#  7   review_total_negative_word_counts           386803 non-null  int64
#  8   total_number_of_reviews                     386803 non-null  int64
#  9   positive_review                             386803 non-null  object
#  10  review_total_positive_word_counts           386803 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  12  reviewer_score                              386803 non-null  float64
#  13  tags                                        386803 non-null  object
#  14  days_since_review                           386803 non-null  object
#  15  lat                                         384355 non-null  float64
#  16  lng                                         384355 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 50.2+ MB

# %%
h1[h1.duplicated(subset=h1.columns)].shape[0]
# Out:
# 307

# %% [markdown]
# Дубликаты найдены, поэтому их удаляем

# %%
h1 = h1.drop_duplicates()

# %% [markdown]
# удаляем также строки с пропусками в полях lat и lng. В других полях нет пустых значений

# %%
h1 = h1.dropna(axis=0, how='all', subset=['lat','lng'])

# %% [markdown]
# преобразуем строковую дату к типу datetime

# %%
h1['review_date'] =  pd.to_datetime(h1['review_date'], format='%m/%d/%Y')

# %%
#h1[h1.hotel_name == '11 Cadogan Gardens'].sort_values(by = ['review_date'])

# %%
#from geopy.geocoders import Nominatim

#geoloc = Nominatim(user_agent="geoapiExercises")

#def get_country(lat1, lon1):
#    if lat1:
#        loc1 = geoloc.reverse(str(lat1)+","+str(lon1))
#        return loc1.raw['address']['country']
#    return ''

# %%
#h1['country'] = h1.apply(lambda x: get_country(x['lat'], x['lng']), axis=1)

# %%
#h1[h1.hotel_name == '45 Park Lane Dorchester Collection'].sort_values(by = ['review_date'])[['review_date','days_since_review','reviewer_score']]

# %% [markdown]
# пишем функцию, которая находит в заданной строке тэг с кол-вом ночей и возвращает это кол-во

# %%
import re

def get_nights( s1 ):
    mt1 = re.search(r'Stayed \d+ night', s1)
    if mt1:
        return int(mt1[0].split()[1])
    return np.NAN

# %% [markdown]
# создали новое поле Nights с кол-вом проведенных ночей, используя только что созданную функцию

# %%
#h1 = h1.drop('Nights', axis=1)

h1['Nights'] = h1.tags.apply(get_nights)

#get_nday(' Stayed  nights ')

# %%
h1[h1['Nights'].isnull()].shape[0]
# Out:
# 145

# %% [markdown]
# удаляем строки с пустыми значениями в поле Nights

# %%
h1.dropna(axis=0, how='all', subset=['Nights'], inplace=True)

# %%
h1[pd.isna(h1.tags)]
# Out:
# Empty DataFrame
# Columns: [hotel_address, additional_number_of_scoring, review_date, average_score, hotel_name, reviewer_nationality, negative_review, review_total_negative_word_counts, total_number_of_reviews, positive_review, review_total_positive_word_counts, total_number_of_reviews_reviewer_has_given, reviewer_score, tags, days_since_review, lat, lng, Nights]
# Index: []

# %% [markdown]
# создали поле month, выделив месяц из поля review_date. Предполагаем, что на оценку отеля может повлиять сезон, а месяц этот сезон и определяет

# %%
h1['month'] = h1.review_date.dt.month

#h1[['tags','Nights']].head(20)

# %%
h1.info()
#h1.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383903 entries, 0 to 386802
# Data columns (total 19 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               383903 non-null  object
#  1   additional_number_of_scoring                383903 non-null  int64
#  2   review_date                                 383903 non-null  datetime64[ns]
#  3   average_score                               383903 non-null  float64
#  4   hotel_name                                  383903 non-null  object
#  5   reviewer_nationality                        383903 non-null  object
#  6   negative_review                             383903 non-null  object
#  7   review_total_negative_word_counts           383903 non-null  int64
#  8   total_number_of_reviews                     383903 non-null  int64
#  9   positive_review                             383903 non-null  object
#  10  review_total_positive_word_counts           383903 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  383903 non-null  int64
#  12  reviewer_score                              383903 non-null  float64
#  13  tags                                        383903 non-null  object
#  14  days_since_review                           383903 non-null  object
#  15  lat                                         383903 non-null  float64
#  16  lng                                         383903 non-null  float64
#  17  Nights                                      383903 non-null  float64
#  18  month                                       383903 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(7)
# memory usage: 58.6+ MB

# %%
h1 = h1.reindex(index=range(0,h1.shape[0]), method='pad')

# %% [markdown]
# смотрим распределение поля страна рецензента

# %%
h1.reviewer_nationality.value_counts(True).head(15)
# Out:
#  United Kingdom               0.477248
#  United States of America     0.068496
#  Australia                    0.042039
#  Ireland                      0.028854
#  United Arab Emirates         0.019711
#  Saudi Arabia                 0.017403
#  Netherlands                  0.017056
#  Switzerland                  0.016801
#  Canada                       0.015374
#  Germany                      0.015301
#  France                       0.014282
#  Israel                       0.012667
#  Italy                        0.011787
#  Belgium                      0.011714
#  Turkey                       0.010557
# Name: reviewer_nationality, dtype: float64

# %% [markdown]
# Выбираем 15 самых часто встречающихся стран, а остальные относим к группе other

# %%
nat1 = h1.reviewer_nationality.value_counts(True).head(15)

# %%
#h1[h1.reviewer_nationality.any(nat1.index)]
h1.reviewer_nationality = h1.reviewer_nationality.apply(lambda x: x if x in nat1.index else 'other')

# %%
h1.reviewer_nationality.value_counts(True)
# Out:
#  United Kingdom               0.477248
# other                         0.220709
#  United States of America     0.068496
#  Australia                    0.042039
#  Ireland                      0.028854
#  United Arab Emirates         0.019711
#  Saudi Arabia                 0.017403
#  Netherlands                  0.017056
#  Switzerland                  0.016801
#  Canada                       0.015374
#  Germany                      0.015301
#  France                       0.014282
#  Israel                       0.012667
#  Italy                        0.011787
#  Belgium                      0.011714
#  Turkey                       0.010557
# Name: reviewer_nationality, dtype: float64

# %% [markdown]
# создаем бинарное поле для каждой страны рецензента

# %%
h1 = pd.get_dummies(h1, columns=['reviewer_nationality'])

# %%
#import category_encoders as ce # импорт для работы с кодировщиком

#bin_encoder = ce.BinaryEncoder(cols=['reviewer_nationality']) # указываем столбец для кодирования

#nationals = bin_encoder.fit_transform( h1['reviewer_nationality'] )
#h1 = pd.concat([h1, nationals], axis=1)


#h1.reviewer_nationality.value_counts(True).head(20)

# %% [markdown]
# ДОБАВЛЕНИЕ НОВЫХ ПРИЗНАКОВ НА ОСНОВЕ ТЭГОВ

# %%
from ast import literal_eval

#  Функция возвращает кол-во тэгов в строке t1
def get_tags_cnt( t1 ):
    m2 = literal_eval( t1 )
    return len(m2)

# %%
#h1.tags.apply( get_tags_cnt )

# %% [markdown]
# создаем поле tags_cnt с кол-вом тэгов в текущей строке

# %%
h1['tags_cnt'] = h1.tags.apply( get_tags_cnt )

# %% [markdown]
# Формируем массив m1, содержащий все тэги из набора данных

# %%
from ast import literal_eval
# m0 = []
m1 = []

for i1 in range(0, h1.shape[0]):
    m2 = literal_eval(h1.loc[i1,'tags'])
    
    m1.extend(m2)
    # m0.extend([m2])
    #print(m2)
m1
# Out:
# [' Leisure trip ',
#  ' Couple ',
#  ' Studio Suite ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Couple ',
#  ' Standard Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Modern Double Room Echo ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Room with 1 Double Bed ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 6 nights ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Superior Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room Non Smoking ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Twin Hilton Guest Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Family with young children ',
#  ' Luxury Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double or Twin Room Non Smoking ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double or Twin Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Standard Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Comfort Double or Twin Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Executive Double Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Twin Room Non Smoking ',
#  ' Stayed 6 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Studio Double Family ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Twin Superior Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' X Ordinary Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' 2 rooms ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' King Deluxe Guest Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Double Studio ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Family with older children ',
#  ' Luxury Double Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Business trip ',
#  ' Couple ',
#  ' Standard Double Room without Window ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Executive Double Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Hypoallergenic Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Premier Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Standard Room with Double Bed and Sofa Bed ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Basic Double Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Classic Double Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe King Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Superior Family Room ',
#  ' Stayed 5 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Guest Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Standard Twin Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Deluxe One Bedroom Apartment ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Travelers with friends ',
#  ' Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Double Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Deluxe Double Room with Eiffel Tower view ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard King Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Studio ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Standard Double or Twin Room with Extra bed 2 Adults 1 Child ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Small Queen Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Art King Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Superior Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Standard Double Room ',
#  ' Stayed 3 nights ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Triple Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Executive Double Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Twin Room Non Smoking ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Solo traveler ',
#  ' Superior Twin Room with Internal View ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Twin Room ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 2 nights ',
#  ' Couple ',
#  ' Classic Double Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Family with young children ',
#  ' Deluxe Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Executive Queen Room with Lounge Access ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 5 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Deluxe Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Deluxe Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' 2 rooms ',
#  ' Stayed 6 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Large Twin Room ',
#  ' Stayed 5 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' 2 rooms ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Group ',
#  ' Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Solo traveler ',
#  ' Double Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Executive King Room ',
#  ' Stayed 5 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Classic Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Single Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Room with Spa access ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Couple ',
#  ' Luxury Suite Patio ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Group ',
#  ' Premium Double or Twin Room with View ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Queen Guest Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Chelsea Twin Suite ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Deluxe King Room ',
#  ' Stayed 5 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Executive Suite ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Room with 1 Single Bed ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Twin Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Hilton Deluxe Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double or Twin Room with Parking ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Queen Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' King Guest Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 5 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Standard Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Family with young children ',
#  ' Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Queen Hilton Guest Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double Room with Park View ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 3 nights ',
#  ' Business trip ',
#  ' Group ',
#  ' Deluxe Twin Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Executive Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Executive Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Executive Studio City View Family ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Deluxe Family Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Superior Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Twin Room Non Smoking ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Queen Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' City Twin Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Comfort Double or Twin Room ',
#  ' Stayed 5 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Double Family Guestroom ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Classic Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Executive Double Room ',
#  ' Stayed 8 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double with Terrace ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Queen Guestroom ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Club Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Basic Double Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Classic Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Large Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' River View Deluxe ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room without Window ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 2 nights ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Superior Double Room Single use ',
#  ' Stayed 2 nights ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Deluxe Single Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room Non Smoking ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Club Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room with View Terrace ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Single Room ',
#  ' Stayed 5 nights ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Queen Room ',
#  ' Stayed 2 nights ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Single Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Apartment for 3 to 4 People with Kitchenette ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Triple Room ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Group ',
#  ' Deluxe Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Twin Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Queen Room ',
#  ' Stayed 6 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double Room without Window ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Deluxe Single Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Room with 1 Double Bed ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room with Courtyard View ',
#  ' Stayed 4 nights ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Classic Single Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Classic Double Room ',
#  ' Stayed 2 nights ',
#  ' Business trip ',
#  ' Couple ',
#  ' Deluxe Double or Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Room with 1 Queen Bed ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe King or Twin Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Queen Guest Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Twin Hilton Guest Room ',
#  ' Stayed 6 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Standard Twin Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Deluxe Double Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Queen Guest Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe King Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Executive King Room ',
#  ' Stayed 7 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Club Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior King Room ',
#  ' Stayed 3 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Studio King ',
#  ' Stayed 5 nights ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Club Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Standard Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Standard Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Single Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Cosy Double Room ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Double Room with Spa Bath ',
#  ' Stayed 5 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with older children ',
#  ' Double Family Guestroom ',
#  ' Stayed 2 nights ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Deluxe Double or Twin Room ',
#  ' Stayed 6 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 8 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Double Room with River View ',
#  ' Stayed 7 nights ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Family with older children ',
#  ' Deluxe Double Room with Two Double Beds ',
#  ' Stayed 10 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Classic Double Room ',
#  ' Stayed 4 nights ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' 2 rooms ',
#  ' Stayed 14 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Queen Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' King Room with River View ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 4 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Deluxe Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Superior Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Comfort Double or Twin Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Double Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Standard Double or Twin Room ',
#  ' Stayed 2 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Triple Room ',
#  ' Stayed 6 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Family with young children ',
#  ' Garden Twin Room ',
#  ' Stayed 14 nights ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Solo traveler ',
#  ' Standard Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Classic Single Room ',
#  ' Stayed 1 night ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Classic Double Room ',
#  ' Stayed 5 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ' Solo traveler ',
#  ' Standard Twin Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Couple ',
#  ' Double Room ',
#  ' Stayed 1 night ',
#  ' Submitted from a mobile device ',
#  ' Leisure trip ',
#  ' Group ',
#  ' Superior Double Room ',
#  ' Stayed 3 nights ',
#  ' Submitted from a mobile device ',
#  ' Business trip ',
#  ...]

# %% [markdown]
# преобразуем массив m1 в датафрэйм df1

# %%
df1 = pd.DataFrame(m1, columns=['tag'])

# %% [markdown]
# удаляем из df1 элементы с информацией о кол-ве ночей (для них у нас уже есть ранее заполненное поле Nights)

# %%
df1 = df1[df1.tag.str.count(' Stayed ') == 0]

# %% [markdown]
# Группируем датафрэйм по названию тэгов и выделяем из них 15 наиболее часто используемых

# %%
#df1.groupby('tag')['tag'].agg(['count'])
df2 = df1.groupby('tag')['tag'].count()
df2.shape[0]
# Out:
# 2314

# %%
df2 = df2.sort_values().tail(15)
df2
# Out:
# tag
#  Classic Double Room                 12607
#  Standard Double or Twin Room        13071
#  Double or Twin Room                 16627
#  Deluxe Double Room                  18585
#  Family with older children          19648
#  Superior Double Room                23357
#  Standard Double Room                23825
#  Double Room                         26336
#  Family with young children          45523
#  Group                               48667
#  Business trip                       61515
#  Solo traveler                       80607
#  Couple                             187845
#  Submitted from a mobile device     229263
#  Leisure trip                       311247
# Name: tag, dtype: int64

# %% [markdown]
# Создаем бинарные поля для 15-и наиболее часто используемых тэгов

# %%
for in1 in df2.index:
    col1 = in1.strip()
    str1 = "'" + in1 + "'"
    h1[col1] = h1.tags.str.count(str1)
    #print(str1)

# %% [markdown]
# анализируем все небинарные числовые поля (вкл.целевое поле reviewer_score)

# %%
cols = ['average_score','review_total_negative_word_counts','review_total_positive_word_counts', 'total_number_of_reviews_reviewer_has_given','total_number_of_reviews', 'additional_number_of_scoring',
        'Nights','month', 'tags_cnt', 'reviewer_score' ]
h1[cols].hist(figsize=(20, 11));


#h1 = h1.drop_duplicates()
#h1[h1.duplicated(subset=h1.columns)]

# %% [markdown]
# Видим, что близко к нормальному распределено только поле average_score. Также видно что почти все поля имеют довольно длинные "хвосты"

# %% [markdown]
# Далее анализируем поле Nights

# %%
h1['Nights'].plot(kind="box", vert=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# принимаем решение считать выбросами все значения > 10

# %%
h1 = h1.drop( h1[h1['Nights'] > 10].index )
#h10 = pd.get_dummies(h1, columns=['reviewer_nationality'])

# %% [markdown]
# Данные в поле average_score распределены более-менее нормально, поэтому для определения выбросов можем использовать метод межквартильного размаха

# %%
def outliers_iqr(data, feature, left=1.5, right=1.5, log_scale=False):
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    # x = data[feature]
    quartile_1, quartile_3 = x.quantile(0.25), x.quantile(0.75),
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * left)
    upper_bound = quartile_3 + (iqr * right)
    
    print(f'Границы диапазона: {lower_bound}, {upper_bound}')
    
    outliers = data[(x<lower_bound) | (x > upper_bound)]
    cleaned = data[(x>lower_bound) & (x < upper_bound)]
    return outliers, cleaned

# %% [markdown]
# Левую границу берем чуть больше стандарта (2 вместо 1.5) т.к. слева распределение имеет более длинный хвост

# %%
out1, h1 = outliers_iqr(h1, 'average_score', left=2.0, right=1.5)
# Out:
# Границы диапазона: 6.6999999999999975, 9.850000000000001

# %% [markdown]
# Определяем границы выбросов по всем числовым полям

# %%
h1.describe()
# Out:
#        additional_number_of_scoring  average_score  \
# count                 381538.000000  381538.000000
# mean                     501.184600       8.404651
# std                      501.544937       0.538043
# min                        1.000000       6.700000
# 25%                      170.000000       8.100000
# 50%                      345.000000       8.400000
# 75%                      666.000000       8.800000
# max                     2682.000000       9.800000
#
#        review_total_negative_word_counts  total_number_of_reviews  \
# count                      381538.000000            381538.000000
# mean                           18.481111              2751.973644
# std                            29.606363              2324.037825
# min                             0.000000                43.000000
# 25%                             2.000000              1161.000000
# 50%                             9.000000              2134.000000
# 75%                            23.000000              3633.000000
# max                           408.000000             16670.000000
#
#        review_total_positive_word_counts  \
# count                      381538.000000
# mean                           17.795349
# std                            21.724633
# min                             0.000000
# 25%                             5.000000
# 50%                            11.000000
# 75%                            22.000000
# max                           386.000000
#
#        total_number_of_reviews_reviewer_has_given  reviewer_score  \
# count                               381538.000000   381538.000000
# mean                                     7.167435        8.406403
# std                                     11.045948        1.628062
# min                                      1.000000        2.500000
# 25%                                      1.000000        7.500000
# 50%                                      3.000000        8.800000
# 75%                                      8.000000        9.600000
# max                                    355.000000       10.000000
#
#                  lat            lng         Nights  ...  Superior Double Room  \
# count  381538.000000  381538.000000  381538.000000  ...         381538.000000
# mean       49.436443       2.830905       2.323818  ...              0.061056
# std         3.471908       4.583484       1.506805  ...              0.239432
# min        41.328376      -0.369758       1.000000  ...              0.000000
# 25%        48.214277      -0.143372       1.000000  ...              0.000000
# 50%        51.499981       0.019886       2.000000  ...              0.000000
# 75%        51.516288       4.834443       3.000000  ...              0.000000
# max        52.400181      16.429233      10.000000  ...              1.000000
#
#        Standard Double Room    Double Room  Family with young children  \
# count         381538.000000  381538.000000               381538.000000
# mean               0.061871       0.067907                    0.118389
# std                0.240921       0.251586                    0.323069
# min                0.000000       0.000000                    0.000000
# 25%                0.000000       0.000000                    0.000000
# 50%                0.000000       0.000000                    0.000000
# 75%                0.000000       0.000000                    0.000000
# max                1.000000       1.000000                    1.000000
#
#                Group  Business trip  Solo traveler         Couple  \
# count  381538.000000  381538.000000  381538.000000  381538.000000
# mean        0.126949       0.159504       0.208957       0.490449
# std         0.332917       0.366146       0.406564       0.499909
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        Submitted from a mobile device   Leisure trip
# count                   381538.000000  381538.000000
# mean                         0.597285       0.811749
# std                          0.490445       0.390913
# min                          0.000000       0.000000
# 25%                          0.000000       1.000000
# 50%                          1.000000       1.000000
# 75%                          1.000000       1.000000
# max                          1.000000       1.000000
#
# [8 rows x 43 columns]

# %%
h1[h1.tags_cnt < 4].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3970 entries, 71 to 383846
# Data columns (total 50 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   hotel_address                                    3970 non-null   object
#  1   additional_number_of_scoring                     3970 non-null   int64
#  2   review_date                                      3970 non-null   datetime64[ns]
#  3   average_score                                    3970 non-null   float64
#  4   hotel_name                                       3970 non-null   object
#  5   negative_review                                  3970 non-null   object
#  6   review_total_negative_word_counts                3970 non-null   int64
#  7   total_number_of_reviews                          3970 non-null   int64
#  8   positive_review                                  3970 non-null   object
#  9   review_total_positive_word_counts                3970 non-null   int64
#  10  total_number_of_reviews_reviewer_has_given       3970 non-null   int64
#  11  reviewer_score                                   3970 non-null   float64
#  12  tags                                             3970 non-null   object
#  13  days_since_review                                3970 non-null   object
#  14  lat                                              3970 non-null   float64
#  15  lng                                              3970 non-null   float64
#  16  Nights                                           3970 non-null   float64
#  17  month                                            3970 non-null   int64
#  18  reviewer_nationality_ Australia                  3970 non-null   uint8
#  19  reviewer_nationality_ Belgium                    3970 non-null   uint8
#  20  reviewer_nationality_ Canada                     3970 non-null   uint8
#  21  reviewer_nationality_ France                     3970 non-null   uint8
#  22  reviewer_nationality_ Germany                    3970 non-null   uint8
#  23  reviewer_nationality_ Ireland                    3970 non-null   uint8
#  24  reviewer_nationality_ Israel                     3970 non-null   uint8
#  25  reviewer_nationality_ Italy                      3970 non-null   uint8
#  26  reviewer_nationality_ Netherlands                3970 non-null   uint8
#  27  reviewer_nationality_ Saudi Arabia               3970 non-null   uint8
#  28  reviewer_nationality_ Switzerland                3970 non-null   uint8
#  29  reviewer_nationality_ Turkey                     3970 non-null   uint8
#  30  reviewer_nationality_ United Arab Emirates       3970 non-null   uint8
#  31  reviewer_nationality_ United Kingdom             3970 non-null   uint8
#  32  reviewer_nationality_ United States of America   3970 non-null   uint8
#  33  reviewer_nationality_other                       3970 non-null   uint8
#  34  tags_cnt                                         3970 non-null   int64
#  35  Classic Double Room                              3970 non-null   int64
#  36  Standard Double or Twin Room                     3970 non-null   int64
#  37  Double or Twin Room                              3970 non-null   int64
#  38  Deluxe Double Room                               3970 non-null   int64
#  39  Family with older children                       3970 non-null   int64
#  40  Superior Double Room                             3970 non-null   int64
#  41  Standard Double Room                             3970 non-null   int64
#  42  Double Room                                      3970 non-null   int64
#  43  Family with young children                       3970 non-null   int64
#  44  Group                                            3970 non-null   int64
#  45  Business trip                                    3970 non-null   int64
#  46  Solo traveler                                    3970 non-null   int64
#  47  Couple                                           3970 non-null   int64
#  48  Submitted from a mobile device                   3970 non-null   int64
#  49  Leisure trip                                     3970 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(22), object(6), uint8(16)
# memory usage: 1.1+ MB

# %% [markdown]
# Удаляем выбросы

# %%
#h1[h1['review_total_negative_word_counts'] > 150].count()  # - 3252

h1 = h1.drop( h1[h1['review_total_negative_word_counts'] > 150].index )

# %%
#h1[h1['review_total_positive_word_counts'] > 150].count()  # - 1210

h1 = h1.drop( h1[h1['review_total_positive_word_counts'] > 150].index )

# %%
#h1[h1['total_number_of_reviews_reviewer_has_given'] > 50].count()  # - 4181

h1 = h1.drop( h1[h1['total_number_of_reviews_reviewer_has_given'] > 50].index )

# %%
#h1[h1['total_number_of_reviews'] > 10000].count()  # - 5181

h1 = h1.drop( h1[h1['total_number_of_reviews'] > 10000].index )

# %%
#h1[h1['additional_number_of_scoring'] > 2000].count()  # - 6643

h1 = h1.drop( h1[h1['additional_number_of_scoring'] > 2000].index )

# %%
# h1[h1.tags_cnt > 5].count()

h1 = h1.drop( h1[h1.tags_cnt > 5].index )

# %% [markdown]
# Смотрим что получилось после удаления выбросов

# %%
h1.describe()
# Out:
#        additional_number_of_scoring  average_score  \
# count                 360661.000000  360661.000000
# mean                     446.650012       8.419136
# std                      381.534058       0.529439
# min                        1.000000       6.700000
# 25%                      166.000000       8.100000
# 50%                      333.000000       8.400000
# 75%                      620.000000       8.800000
# max                     1936.000000       9.800000
#
#        review_total_negative_word_counts  total_number_of_reviews  \
# count                      360661.000000            360661.000000
# mean                           16.622887              2484.649715
# std                            22.351425              1759.575798
# min                             0.000000                43.000000
# 25%                             0.000000              1131.000000
# 50%                             9.000000              2037.000000
# 75%                            23.000000              3469.000000
# max                           150.000000              8177.000000
#
#        review_total_positive_word_counts  \
# count                      360661.000000
# mean                           17.196664
# std                            18.706578
# min                             0.000000
# 25%                             5.000000
# 50%                            11.000000
# 75%                            22.000000
# max                           150.000000
#
#        total_number_of_reviews_reviewer_has_given  reviewer_score  \
# count                               360661.000000   360661.000000
# mean                                     6.437499        8.443696
# std                                      8.041168        1.600957
# min                                      1.000000        2.500000
# 25%                                      1.000000        7.500000
# 50%                                      3.000000        8.800000
# 75%                                      8.000000        9.600000
# max                                     50.000000       10.000000
#
#                  lat            lng         Nights  ...  Superior Double Room  \
# count  360661.000000  360661.000000  360661.000000  ...         360661.000000
# mean       49.412109       2.852517       2.335234  ...              0.062078
# std         3.497777       4.593787       1.509649  ...              0.241297
# min        41.328376      -0.369758       1.000000  ...              0.000000
# 25%        48.214066      -0.145279       1.000000  ...              0.000000
# 50%        51.499279       0.038657       2.000000  ...              0.000000
# 75%        51.516843       4.834443       3.000000  ...              0.000000
# max        52.400181      16.429233      10.000000  ...              1.000000
#
#        Standard Double Room    Double Room  Family with young children  \
# count         360661.000000  360661.000000               360661.000000
# mean               0.060348       0.066117                    0.118019
# std                0.238130       0.248488                    0.322632
# min                0.000000       0.000000                    0.000000
# 25%                0.000000       0.000000                    0.000000
# 50%                0.000000       0.000000                    0.000000
# 75%                0.000000       0.000000                    0.000000
# max                1.000000       1.000000                    1.000000
#
#                Group  Business trip  Solo traveler         Couple  \
# count  360661.000000  360661.000000  360661.000000  360661.000000
# mean        0.127990       0.156183       0.205470       0.492917
# std         0.334079       0.363029       0.404045       0.499951
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        Submitted from a mobile device   Leisure trip
# count                   360661.000000  360661.000000
# mean                         0.601446       0.815062
# std                          0.489601       0.388248
# min                          0.000000       0.000000
# 25%                          0.000000       1.000000
# 50%                          1.000000       1.000000
# 75%                          1.000000       1.000000
# max                          1.000000       1.000000
#
# [8 rows x 43 columns]

# %%
h1 = h1.reindex(index=range(0,h1.shape[0]), method='pad')

# %% [markdown]
# ПРЕОБРАЗОВАНИЕ ПРИЗНАКОВ

# %%
from sklearn import preprocessing
s_scaler = preprocessing.StandardScaler()

# %% [markdown]
# Поле average_score распределено более-менее нормально, поэтому для него выполняем стандартитзацию, а не нормализацию

# %%
as1 = s_scaler.fit_transform( h1[['average_score']] )
as1 = pd.DataFrame(as1, columns=['average_score'] )

# %%
h1 = h1.drop('average_score', axis=1)
h1 = pd.concat([h1, as1], axis=1)

# %% [markdown]
# Для всех прочих числовых (но не бинарных) признаков выполняем нормализацию, причем используем метод RobustScaler, т.к. он менее чувствителен к выбросам

# %%
r_scaler = preprocessing.RobustScaler()
col_names = ['review_total_negative_word_counts','review_total_positive_word_counts', 'total_number_of_reviews_reviewer_has_given','total_number_of_reviews', 'additional_number_of_scoring',
        'Nights','month', 'tags_cnt' ]

h2 = r_scaler.fit_transform(h1[col_names])

# Преобразуем промежуточный датасет в полноценный датафрейм для визуализации
h2 = pd.DataFrame(h2, columns=col_names)

# %%
h1 = h1.drop(col_names, axis=1)

h1 = pd.concat([h1, h2], axis=1)

# %% [markdown]
# Смотрим что получилось после преобразования признаков.

# %%
cols = ['average_score','review_total_negative_word_counts','review_total_positive_word_counts', 'total_number_of_reviews_reviewer_has_given','total_number_of_reviews', 'additional_number_of_scoring',
        'Nights','month', 'tags_cnt', 'reviewer_score' ]
h1[cols].hist(figsize=(20, 11));

# %%
h1[pd.isna(h1.tags)]
# Out:
# Empty DataFrame
# Columns: [hotel_address, review_date, hotel_name, negative_review, positive_review, reviewer_score, tags, days_since_review, lat, lng, reviewer_nationality_ Australia , reviewer_nationality_ Belgium , reviewer_nationality_ Canada , reviewer_nationality_ France , reviewer_nationality_ Germany , reviewer_nationality_ Ireland , reviewer_nationality_ Israel , reviewer_nationality_ Italy , reviewer_nationality_ Netherlands , reviewer_nationality_ Saudi Arabia , reviewer_nationality_ Switzerland , reviewer_nationality_ Turkey , reviewer_nationality_ United Arab Emirates , reviewer_nationality_ United Kingdom , reviewer_nationality_ United States of America , reviewer_nationality_other, Classic Double Room, Standard Double or Twin Room, Double or Twin Room, Deluxe Double Room, Family with older children, Superior Double Room, Standard Double Room, Double Room, Family with young children, Group, Business trip, Solo traveler, Couple, Submitted from a mobile device, Leisure trip, average_score, review_total_negative_word_counts, review_total_positive_word_counts, total_number_of_reviews_reviewer_has_given, total_number_of_reviews, additional_number_of_scoring, Nights, month, tags_cnt]
# Index: []
#
# [0 rows x 50 columns]

# %%
h1.columns
# Out:
# Index(['hotel_address', 'review_date', 'hotel_name', 'negative_review',
#        'positive_review', 'reviewer_score', 'tags', 'days_since_review', 'lat',
#        'lng', 'reviewer_nationality_ Australia ',
#        'reviewer_nationality_ Belgium ', 'reviewer_nationality_ Canada ',
#        'reviewer_nationality_ France ', 'reviewer_nationality_ Germany ',
#        'reviewer_nationality_ Ireland ', 'reviewer_nationality_ Israel ',
#        'reviewer_nationality_ Italy ', 'reviewer_nationality_ Netherlands ',
#        'reviewer_nationality_ Saudi Arabia ',
#        'reviewer_nationality_ Switzerland ', 'reviewer_nationality_ Turkey ',
#        'reviewer_nationality_ United Arab Emirates ',
#        'reviewer_nationality_ United Kingdom ',
#        'reviewer_nationality_ United States of America ',
#        'reviewer_nationality_other', 'Classic Double Room',
#        'Standard Double or Twin Room', 'Double or Twin Room',
#        'Deluxe Double Room', 'Family with older children',
#        'Superior Double Room', 'Standard Double Room', 'Double Room',
#        'Family with young children', 'Group', 'Business trip', 'Solo traveler',
#        'Couple', 'Submitted from a mobile device', 'Leisure trip',
#        'average_score', 'review_total_negative_word_counts',
#        'review_total_positive_word_counts',
#        'total_number_of_reviews_reviewer_has_given', 'total_number_of_reviews',
#        'additional_number_of_scoring', 'Nights', 'month', 'tags_cnt'],
#       dtype='object')

# %%
#h1[['tags','Solo traveler']]

# %% [markdown]
# Формируем тепловую карту для выявления мультиколлинеарных признаков

# %%
import plotly.express as px

px.imshow(h1.corr(), text_auto=True, width = 1400, height=1400)  # , aspect="auto"

#import seaborn as sns
#sns.heatmap(h1.corr(), annot = False)
# Out:
# C:\Users\Glavatskih-DE\AppData\Local\Temp\ipykernel_7316\2598296963.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# Очевидно есть только две пары сильно коррелирующих признаков - Business trip + Leisure trip (коэф.кор.~-0.9) и tags_cnt + Submitted from a mobile device ((коэф.кор.~0.94))
# По одному признаку из каждой пары имеет смысл удалить, но какие именно - выясним дальше когда сравним их значимость

# %%
# непрерывные признаки
num_cols = ['average_score','review_total_negative_word_counts','review_total_positive_word_counts', 'total_number_of_reviews_reviewer_has_given','total_number_of_reviews', 'additional_number_of_scoring',
        'Nights','month', 'tags_cnt', 'lat', 'lng' ]   # , 'reviewer_score'
# категориальные и бинарные признаки 
cat_cols = ['Classic Double Room', 'Standard Double or Twin Room',
       'Double or Twin Room', 'Deluxe Double Room',
       'Family with older children', 'Standard Double Room',
       'Superior Double Room', 'Double Room', 'Family with young children',
       'Group', 'Business trip', 'Solo traveler', 'Couple',
       'Submitted from a mobile device', 'Leisure trip',
       'reviewer_nationality_ Australia ', 'reviewer_nationality_ Belgium ',
       'reviewer_nationality_ Canada ', 'reviewer_nationality_ France ',
       'reviewer_nationality_ Germany ', 'reviewer_nationality_ Ireland ',
       'reviewer_nationality_ Israel ', 'reviewer_nationality_ Italy ',
       'reviewer_nationality_ Netherlands ',
       'reviewer_nationality_ Saudi Arabia ',
       'reviewer_nationality_ Switzerland ', 'reviewer_nationality_ Turkey ',
       'reviewer_nationality_ United Arab Emirates ',
       'reviewer_nationality_ United Kingdom ',
       'reviewer_nationality_ United States of America ',
       'reviewer_nationality_other']

# %%
# Разбиваем датафрейм на части, необходимые для обучения и тестирования модели  
# Х - данные с информацией об отелях, у - целевая переменная (рейтинги отелей)  
X = h1.drop(['reviewer_score'], axis = 1)  
y = h1['reviewer_score']

# %% [markdown]
# Для оценки значимость категориальных и бинарных признаков используем метод хи-квадрат

# %%
y=y.astype('int')
from sklearn.feature_selection import chi2 # хи-квадрат

imp_cat = pd.Series(chi2(X[cat_cols], y)[0], index=cat_cols)
imp_cat.sort_values(inplace = True)
imp_cat.plot(kind = 'barh')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Удаляем признаки со значимостью менее 200

# %%
h1.drop(imp_cat[imp_cat < 200].index, axis=1, inplace=True)

# %% [markdown]
# Удаляем признак Leisure trip т.к. он менее значим, чем Business trip и сильно с ним коррелирует.

# %%
h1.drop(['Leisure trip'], axis=1, inplace=True)

# %% [markdown]
# Для оценки значимость непрерывных признаков используем тест ANOVA

# %%
from sklearn.feature_selection import f_classif # anova

imp_num = pd.Series(f_classif(X[num_cols], y)[0], index = num_cols)
imp_num.sort_values(inplace = True)
imp_num.plot(kind = 'barh')
# Out:
# <AxesSubplot: >

# %%
imp_num
# Out:
# month                                           52.415426
# Nights                                          54.754426
# lat                                             54.976104
# additional_number_of_scoring                    75.035894
# lng                                             80.127997
# total_number_of_reviews                        167.933559
# tags_cnt                                       172.085083
# total_number_of_reviews_reviewer_has_given     275.957418
# review_total_positive_word_counts             3009.314375
# average_score                                 6717.495961
# review_total_negative_word_counts             8642.348293
# dtype: float64

# %% [markdown]
# Удаляем признаки со значимостью менее 200

# %%
h1.drop(imp_num[imp_num < 200].index, axis=1, inplace=True)
#imp_num[imp_num < 200].index

# %% [markdown]
# Удаляем из набора данных все объектные типы и дату

# %%
object_columns = [s for s in h1.columns if h1[s].dtypes in ['object','datetime64[ns]'] ]
h1.drop(object_columns, axis = 1, inplace=True)
#h1.info()
#object_columns

# %%
X = h1.drop(['reviewer_score'], axis = 1)  
y = h1['reviewer_score']

# %%
# Загружаем специальный инструмент для разбивки:  
from sklearn.model_selection import train_test_split

# %%
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.  
# Для тестирования мы будем использовать 25% от исходного датасета.  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Импортируем необходимые библиотеки:  
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели  
from sklearn import metrics # инструменты для оценки точности модели  
  
# Создаём модель  
regr = RandomForestRegressor(n_estimators=100)  
      
# Обучаем модель на тестовом наборе данных  
regr.fit(X_train, y_train)  
      
# Используем обученную модель для предсказания рейтинга отелей в тестовой выборке.  
# Предсказанные значения записываем в переменную y_pred  
y_pred = regr.predict(X_test)

# %%
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они отличаются  
# Метрика называется Mean Absolute Percentage Error (MAPE) и показывает среднюю абсолютную процентную ошибку предсказанных значений от фактических.  
print('MAPE:', metrics.mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MAPE: 0.1293926650093441
